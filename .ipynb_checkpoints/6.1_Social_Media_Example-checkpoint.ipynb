# %% [markdown]
# # 6.1 Social Media: Example

# %%
import pandas as pd

import numpy as np

# %%
page = pd.read_csv('social_media_demo.csv')

# %%
page.head(10)
# Out:
#   status_type status_published  num_reactions  num_comments  num_shares  \
# 0       video  4/30/2018 11:00           3742            55         436
# 1       photo  4/28/2018 11:00           2923            40         156
# 2       photo  4/27/2018 11:00           3751            27         142
# 3       video  4/26/2018 11:00           4542            82         258
# 4       video  4/25/2018 11:00          10191           159        1473
# 5       video  4/23/2018 12:20            805            25          99
# 6       video  4/18/2018 12:00          39038          1382        9351
# 7       video   4/17/2018 4:00             20             0           0
# 8       video  4/16/2018 11:47           4033            65         521
# 9       video  4/15/2018 11:00            895            12          63
#
#    num_likes  num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0       3156        521        60          5         0           0
# 1       2564        302        56          1         0           0
# 2       3321        400        27          2         1           0
# 3       3955        528        48         11         0           0
# 4       8722       1351       107          8         2           1
# 5        683        110        12          0         0           0
# 6      28777       9035      1184         26        13           3
# 7         18          2         0          0         0           0
# 8       3305        665        60          2         0           1
# 9        806         84         2          0         0           3

# %%
page.shape
# Out:
# (285, 11)

# %%
page.groupby('status_type').sum()
# Out:
#              num_reactions  num_comments  num_shares  num_likes  num_loves  \
# status_type
# link                116194          1662        6341     104358      10905
# photo              4710927         32553      145939    4369615     293974
# video              6435994        122816      846775    5568259     726281
#
#              num_wows  num_hahas  num_sads  num_angrys
# status_type
# link              843         36        16           8
# photo           43055       3116       586         506
# video          128462       8773      1657        1822

# %%
page1= page.loc[:,'num_reactions':'num_angrys']

# %%
page1.head(5)
# Out:
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0           3742            55         436       3156        521        60
# 1           2923            40         156       2564        302        56
# 2           3751            27         142       3321        400        27
# 3           4542            82         258       3955        528        48
# 4          10191           159        1473       8722       1351       107
#
#    num_hahas  num_sads  num_angrys
# 0          5         0           0
# 1          1         0           0
# 2          2         1           0
# 3         11         0           0
# 4          8         2           1

# %%
page.describe()
# Out:
#        num_reactions  num_comments     num_shares      num_likes  \
# count     285.000000    285.000000     285.000000     285.000000
# mean    39519.701754    550.985965    3505.456140   35235.901754
# std     98053.257814   1410.605778   11403.267424   88776.454844
# min        20.000000      0.000000       0.000000      18.000000
# 25%      4676.000000     50.000000     272.000000    4264.000000
# 50%      8077.000000    104.000000     539.000000    7077.000000
# 75%     19214.000000    344.000000    1841.000000   16269.000000
# max    908718.000000  13025.000000  137713.000000  854778.000000
#
#           num_loves      num_wows    num_hahas    num_sads  num_angrys
# count    285.000000    285.000000   285.000000  285.000000  285.000000
# mean    3618.105263    604.771930    41.842105    7.926316    8.196491
# std     8602.987218   2313.098431   135.898133   21.875243   32.381800
# min        1.000000      0.000000     0.000000    0.000000    0.000000
# 25%      446.000000     32.000000     2.000000    0.000000    0.000000
# 50%      876.000000     67.000000     5.000000    1.000000    1.000000
# 75%     2652.000000    218.000000    19.000000    4.000000    4.000000
# max    64559.000000  25541.000000  1815.000000  213.000000  458.000000

# %% [markdown]
# ### Missing Value

# %%
page1.isnull().any().any()
# Out:
# False

# %% [markdown]
# ## Outlier Detection
#
# Why care about outliers? There are a couple of reasons:
#
# Outliers distort the picture of the data we obtain using descriptive statitics and data visualization. When our goal is to understand the data, it is often worthwhile to disregard outliers.
# Outliers play havoc with many machine learning algorithms and statistical models. When our goal is to predict, our models are often improved by ignoring outliers.
# Outliers can be exactly what we want to learn about, especially for tasks like anomaly detection.
#
# More [info](http://colingorrie.github.io/outlier-detection.html)

# %% [markdown]
# ### Method 1 - IQR
#
# It was developed by [John Tukey](https://www.google.com/search?q=john+tukey+outliers&oq=john+tukey+outliers&aqs=chrome..69i57.4843j0j7&sourceid=chrome&ie=UTF-8)

# %% [markdown]
# A box-and-whisker plot uses quartiles (points that divide the data into four groups of equal size) to plot the shape of the data. The box represents the 1st and 3rd quartiles, which are equal to the 25th and 75th percentiles. The line inside the box represents the 2nd quartile, which is the median.
#
# The interquartile range, which gives this method of outlier detection its name, is the range between the first and the third quartiles (the edges of the box). Tukey considered any data point that fell outside of either 1.5 times the IQR below the first – or 1.5 times the IQR above the third – quartile to be “outside” or “far out”. In a classic box-and-whisker plot, the ‘whiskers’ extend up to the last data point that is not “outside”.

# %%
def outliers_iqr(ys):
    quartile_1, quartile_3 = np.percentile(ys, [25, 75])
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * 1.5) #lower fence
    upper_bound = quartile_3 + (iqr * 1.5) #upper fence
    return np.where((ys > upper_bound) | (ys < lower_bound)) #detect outliers

# %% [markdown]
# #### to get the positions (indexes) of outliers

# %%
pos = outliers_iqr(page1.num_reactions)
pos
# Out:
# (array([ 42,  43,  44,  76,  79,  81, 102, 103, 104, 105, 106, 125, 135,
#         136, 137, 138, 146, 147, 153, 154, 163, 167, 169, 170, 171, 172,
#         173, 175, 188, 194, 209, 210, 211, 218, 229, 230, 231, 235, 239,
#         240, 241, 242, 243, 252, 253, 254, 259, 263, 273, 274, 275, 276],
#        dtype=int64),)

# %% [markdown]
# #### to get the reactions correponding to first pos, ie index=42

# %%
page1.iloc[pos[0][0]]
# Out:
# num_reactions    98699
# num_comments       584
# num_shares        3505
# num_likes        92297
# num_loves         5532
# num_wows           733
# num_hahas          100
# num_sads            21
# num_angrys          16
# Name: 42, dtype: int64

# %% [markdown]
# #### to get the reactions correponding to all outliers

# %%
page1.iloc[pos[0]]
# Out:
#      num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 42           98699           584        3505      92297       5532       733
# 43           92646          2926       26036      69626      19292      3576
# 44          174330          1589        8897     152036      19410      2583
# 76           85654          1191        6904      75302       8649      1552
# 79           76117           839        4300      66429       8766       850
# 81           54988           530        3623      48144       5846       928
# 102          63445           488        2951      59393       3586       412
# 103          54202           656        4287      48258       4763      1127
# 104          95844          1773       13660      84951       9210      1593
# 105          78151           344        1379      73280       4421       391
# 106          76169           232         816      72799       2847       465
# 125          60440           822        2586      56294       3605       452
# 135          92753          1665       11130      81860       9208      1478
# 136         172857          2881       12572     154625      14220      3244
# 137          86418          2860       19394      72976      10727      2478
# 138          67884           271        1841      63131       4355       353
# 146          58204          1058        4098      53254       3794      1062
# 147          43720           399        1217      39397       4010       287
# 153          65397           291        1691      62366       2634       341
# 154          72358           742        4505      67541       4409       328
# 163          42843           426        1426      39094       3438       254
# 167          62408          1128        3490      57192       4527       545
# 169         462677          7867       64788     375849      61581     24039
# 170         327020          2787       20468     293724      28920      3942
# 171         497838          8207       55979     436094      52245      8871
# 172         908718          3900       20596     854778      47214      5970
# 173         359140          2020        6460     341886      12894      4179
# 175          64611          2420       11917      50751      12743       997
# 188          76119          2318        8084      62204      13192       511
# 194          81583           945        5872      75539       5250       672
# 209         261837          2765       24738     232472      26001      3012
# 210         188042          4134       30459     164502      20111      3088
# 211         610603          3162       19054     573664      32629      4003
# 218          64104          1356        4703      57977       5065       605
# 229         169128          3344       14810     144560      22155      1975
# 230          62325           642        2701      56418       4998       804
# 231          58361           367        1020      55324       2720       256
# 235          79083          5477        5601      70522       5699       710
# 239         204315          1368        4230     191933       8923      3348
# 240         240126          1218        3926     230451       7577      1988
# 241          52208          1267        6842      45049       5153      1924
# 242         243521          2356        7771     223302      15028      5062
# 243          92374           837        2327      86304       5332       594
# 252         140472          1888       12976     120430      18568      1350
# 253         238562          6217       40901     208995      24144      5102
# 254         333693          1964        9633     314584      16366      2425
# 259          65997           873        4892      61349       4236       317
# 263          65953          1076       10866      59312       5995       534
# 273         435955         13025      137713     345381      64559     25541
# 274         255135          3847       31426     224188      27721      2926
# 275         355879         10007       70529     301651      47040      6643
# 276         404867          2680       16363     370449      30112      3957
#
#      num_hahas  num_sads  num_angrys
# 42         100        21          16
# 43          83        18          51
# 44         237        19          45
# 76         122        14          15
# 79          54        11           7
# 81          55         7           8
# 102         36         7          11
# 103         38         5          11
# 104         60        19          11
# 105         40         8          11
# 106         42         9           7
# 125         58        17          14
# 135        142        37          28
# 136        595       100          73
# 137        193        28          16
# 138         38         6           1
# 146         71        15           8
# 147         20         3           3
# 153         44         6           5
# 154         57        10          13
# 163         44         8           5
# 167        103        22          19
# 169        529       213         458
# 170        313        52          62
# 171        459        96          67
# 172        583       104          68
# 173        138        21          18
# 175         64        20          12
# 188        154        16          19
# 194         75        19          15
# 209        214        50          33
# 210        177        52          46
# 211        236        47          18
# 218        235        44          67
# 229        306        42          80
# 230         50        14          11
# 231         26         7           7
# 235       1815       130         204
# 239         75        30           6
# 240         71        28          11
# 241         49        18          15
# 242         88        37           4
# 243        108        20          16
# 252         90        20          14
# 253        233        53          35
# 254        261        30          27
# 259         67        17          11
# 263         76        19          16
# 273        303        93          38
# 274        222        39          39
# 275        327       126          89
# 276        260        46          43

# %% [markdown]
# #### Let us investigate the post with the highest number of reactions

# %%
page1.num_reactions.values.argmax() # to get the index
# Out:
# 172

# %%
page1.iloc[172].num_reactions
# Out:
# 908718

# %% [markdown]
# #### Method 2 - Z-score method
#
# The Z-score, or standard score, is a way of describing a data point in terms of its relationship to the mean and standard deviation of a group of points. Taking a Z-score is simply mapping the data onto a distribution whose mean is defined as 0 and whose standard deviation is defined as 1.
#
# The goal of taking Z-scores is to remove the effects of the location and scale of the data, allowing different datasets to be compared directly. The intuition behind the Z-score method of outlier detection is that, once we’ve centred and rescaled the data, anything that is too far from zero (the threshold is usually a Z-score of 3 or -3) should be considered an outlier.

# %%
import numpy as np

def outliers_z_score(ys):
    threshold = 3

    mean_y = np.mean(ys)
    stdev_y = np.std(ys)
    z_scores = [(y - mean_y) / stdev_y for y in ys]
    return np.where(np.abs(z_scores) > threshold)

# %% [markdown]
# #### Note:
#
# The Z-score method relies on the mean and standard deviation of a group of data to measure central tendency and dispersion. This is troublesome, because the mean and standard deviation are highly affected by outliers – they are not **robust**. In fact, the skewing that outliers bring is one of the biggest reasons for finding and removing outliers from a dataset!

# %% [markdown]
# #### Method 3 - Modified Z-score method
#
# Another drawback of the Z-score method is that it behaves strangely in small datasets – in fact, the Z-score method will never detect an outlier if the dataset has fewer than 12 items in it. This motivated the development of a modified Z-score method, which does not suffer from the same limitation

# %%
import numpy as np

def outliers_modified_z_score(ys):
    threshold = 3 #lower threshold, more outliers will be detected

    median_y = np.median(ys)
    median_absolute_deviation_y = np.median([np.abs(y - median_y) for y in ys])
    modified_z_scores = [0.6745 * (y - median_y) / median_absolute_deviation_y
                         for y in ys]
    return np.where(np.abs(modified_z_scores) > threshold)

# %% [markdown]
# ## Exercise
#
# Use method 3 to get the outliers for all columns of chanel1

# %%
# find outlier (use modified z-score) for column num_shares
pos2 = outliers_modified_z_score(page1.num_shares)
pos2
# Out:
# (array([  6,  41,  42,  43,  44,  45,  49,  59,  73,  76,  77,  78,  79,
#          81,  93, 102, 103, 104, 122, 125, 135, 136, 137, 143, 145, 146,
#         150, 154, 167, 168, 169, 170, 171, 172, 173, 175, 176, 188, 194,
#         202, 209, 210, 211, 218, 222, 226, 229, 230, 235, 237, 238, 239,
#         240, 241, 242, 243, 245, 246, 252, 253, 254, 259, 262, 263, 273,
#         274, 275, 276, 281, 284], dtype=int64),)

# %%
# use modified z-score to identify outlier for column num_likes
pos3 = outliers_modified_z_score(page1.num_likes)
pos3
# Out:
# (array([  6,  42,  43,  44,  45,  76,  79,  81, 102, 103, 104, 105, 106,
#         125, 135, 136, 137, 138, 146, 147, 153, 154, 163, 167, 169, 170,
#         171, 172, 173, 175, 188, 194, 202, 209, 210, 211, 218, 222, 229,
#         230, 231, 235, 237, 238, 239, 240, 241, 242, 243, 252, 253, 254,
#         259, 262, 263, 273, 274, 275, 276], dtype=int64),)

# %% [markdown]
# ## Demo: Clustering

# %%
page['Dates'] = pd.to_datetime(page.status_published,format="%m/%d/%Y %H:%M").dt.date
page['Time'] = pd.to_datetime(page.status_published,format="%m/%d/%Y %H:%M").dt.time

# %%
page2 = page.groupby('Dates').median()
page2
# Out:
#             num_reactions  num_comments  num_shares  num_likes  num_loves  \
# Dates
# 2017-01-01        26008.0         318.0      2316.0    23075.0     2786.0
# 2017-01-05         6854.0         111.0       492.0     6182.0      596.0
# 2017-01-10         7084.0          83.0       537.0     6403.0      623.0
# 2017-01-11        18704.0         426.0      3686.0    16480.0     2044.0
# 2017-01-14         8260.0         105.0       405.0     7679.0      526.0
# ...                   ...           ...         ...        ...        ...
# 2018-04-25        10191.0         159.0      1473.0     8722.0     1351.0
# 2018-04-26         4542.0          82.0       258.0     3955.0      528.0
# 2018-04-27         3751.0          27.0       142.0     3321.0      400.0
# 2018-04-28         2923.0          40.0       156.0     2564.0      302.0
# 2018-04-30         3742.0          55.0       436.0     3156.0      521.0
#
#             num_wows  num_hahas  num_sads  num_angrys
# Dates
# 2017-01-01     136.0        8.0       3.0         0.0
# 2017-01-05      65.0        7.0       4.0         0.0
# 2017-01-10      54.0        3.0       1.0         0.0
# 2017-01-11     170.0        7.0       1.0         2.0
# 2017-01-14      48.0        5.0       1.0         1.0
# ...              ...        ...       ...         ...
# 2018-04-25     107.0        8.0       2.0         1.0
# 2018-04-26      48.0       11.0       0.0         0.0
# 2018-04-27      27.0        2.0       1.0         0.0
# 2018-04-28      56.0        1.0       0.0         0.0
# 2018-04-30      60.0        5.0       0.0         0.0
#
# [267 rows x 9 columns]

# %%
page2.describe()
# Out:
#        num_reactions  num_comments     num_shares      num_likes  \
# count     267.000000    267.000000     267.000000     267.000000
# mean    40968.262172    571.994382    3661.983146   36528.443820
# std    100731.210810   1445.409019   11742.270980   91227.841139
# min        20.000000      0.000000       0.000000      18.000000
# 25%      4722.500000     52.500000     275.500000    4307.000000
# 50%      8190.000000    105.000000     539.000000    7128.000000
# 75%     21160.500000    369.500000    2206.500000   17831.250000
# max    908718.000000  13025.000000  137713.000000  854778.000000
#
#           num_loves      num_wows    num_hahas    num_sads  num_angrys
# count    267.000000    267.000000   267.000000  267.000000  267.000000
# mean    3742.250936    634.397004    43.344569    8.265918    8.501873
# std     8807.517026   2385.188357   139.423852   22.462259   33.190029
# min        1.000000      0.000000     0.000000    0.000000    0.000000
# 25%      461.000000     34.000000     2.000000    0.000000    0.000000
# 50%      903.000000     68.000000     5.000000    1.000000    1.000000
# 75%     2734.000000    213.500000    19.750000    4.000000    4.500000
# max    64559.000000  25541.000000  1815.000000  213.000000  458.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(page2.num_wows, page2.num_reactions);
plt.xlabel('num_wows')
plt.ylabel('num_reactions')
plt.title('Scatterplot')

# if wow and num_reaction is best-fit, they are strongly related
# else if very scattered, they are not related to each other
# Out:
# Text(0.5, 1.0, 'Scatterplot')

# %%
# dist = pd.concat([page2.num_wows, page2.num_reactions], axis=1, join_axes=[page2.num_wows.index])
# dist

dist = pd.concat([page2.num_wows, page2.num_reactions], axis=1)
dist = dist.reindex(page2.num_wows.index)

# %%
dist.head(5)
# Out:
#             num_wows  num_reactions
# Dates
# 2017-01-01     136.0        26008.0
# 2017-01-05      65.0         6854.0
# 2017-01-10      54.0         7084.0
# 2017-01-11     170.0        18704.0
# 2017-01-14      48.0         8260.0

# %%
dist.tail(5)
# Out:
#             num_wows  num_reactions
# Dates
# 2018-04-25     107.0        10191.0
# 2018-04-26      48.0         4542.0
# 2018-04-27      27.0         3751.0
# 2018-04-28      56.0         2923.0
# 2018-04-30      60.0         3742.0

# %%
#clustering method 1: KMeans

# 1. choose model
from sklearn.cluster import KMeans
# 2. instantiate model
# Kmeans(), by default n_clusters = 3 
# (questionable since i got 8 clusters by putting no arguments)
kmeans = KMeans(n_clusters = 3) 
# 3. fit model to data
kmeans.fit(dist)
# 4. predict
y_kmeans = kmeans.predict(dist)

#evaluate performance

# %%
plt.scatter(dist.num_wows, dist.num_reactions);
centers = kmeans.cluster_centers_
print(centers)
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
plt.xlabel('num_wows')
plt.ylabel('num_reactions')
plt.title('Date -  Clustering')

# [[6.46764706e+03 3.03282000e+05] # coordinate for center 1
#  [1.99439516e+02 1.71911734e+04] # center 2
#  [4.98650000e+03 7.59660500e+05]] # center 3
# Out:
# [[1.99439516e+02 1.71911734e+04]
#  [6.31743750e+03 2.91122250e+05]
#  [6.28133333e+03 6.72386333e+05]]
# Text(0.5, 1.0, 'Date -  Clustering')

# %% [markdown]
# ## Another Example

# %%
page1.corr()

# Correlation coefficient | Interpretation of r
# (absolute value)        | 
# 0.00 - 0.19             | very weak
# 0.20 - 0.39             | weak
# 0.40 - 0.69             | moderate
# 0.70 - 0.89             | strong
# 0.90 - 1.00             | very strong
# Out:
#                num_reactions  num_comments  num_shares  num_likes  num_loves  \
# num_reactions       1.000000      0.755614    0.668469   0.998243   0.895817
# num_comments        0.755614      1.000000    0.945788   0.721004   0.926385
# num_shares          0.668469      0.945788    1.000000   0.627153   0.892180
# num_likes           0.998243      0.721004    0.627153   1.000000   0.868439
# num_loves           0.895817      0.926385    0.892180   0.868439   1.000000
# num_wows            0.698814      0.857601    0.908012   0.659955   0.874015
# num_hahas           0.548865      0.640949    0.425921   0.539957   0.547224
# num_sads            0.768386      0.861429    0.735427   0.743754   0.851886
# num_angrys          0.509459      0.622142    0.514355   0.481149   0.639536
#
#                num_wows  num_hahas  num_sads  num_angrys
# num_reactions  0.698814   0.548865  0.768386    0.509459
# num_comments   0.857601   0.640949  0.861429    0.622142
# num_shares     0.908012   0.425921  0.735427    0.514355
# num_likes      0.659955   0.539957  0.743754    0.481149
# num_loves      0.874015   0.547224  0.851886    0.639536
# num_wows       1.000000   0.431404  0.789370    0.688157
# num_hahas      0.431404   1.000000  0.793677    0.680007
# num_sads       0.789370   0.793677  1.000000    0.866861
# num_angrys     0.688157   0.680007  0.866861    1.000000

# %%
corr = page1.corr()

# %%
import seaborn as sns
# %matplotlib inline

# %%
# plot the heatmap
# visualise correlation
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
# Out:
# <AxesSubplot:>

# %%
corr[corr>0.7] # use 0.7 as threshold (strong to very strong)
# Out:
#                num_reactions  num_comments  num_shares  num_likes  num_loves  \
# num_reactions       1.000000      0.755614         NaN   0.998243   0.895817
# num_comments        0.755614      1.000000    0.945788   0.721004   0.926385
# num_shares               NaN      0.945788    1.000000        NaN   0.892180
# num_likes           0.998243      0.721004         NaN   1.000000   0.868439
# num_loves           0.895817      0.926385    0.892180   0.868439   1.000000
# num_wows                 NaN      0.857601    0.908012        NaN   0.874015
# num_hahas                NaN           NaN         NaN        NaN        NaN
# num_sads            0.768386      0.861429    0.735427   0.743754   0.851886
# num_angrys               NaN           NaN         NaN        NaN        NaN
#
#                num_wows  num_hahas  num_sads  num_angrys
# num_reactions       NaN        NaN  0.768386         NaN
# num_comments   0.857601        NaN  0.861429         NaN
# num_shares     0.908012        NaN  0.735427         NaN
# num_likes           NaN        NaN  0.743754         NaN
# num_loves      0.874015        NaN  0.851886         NaN
# num_wows       1.000000        NaN  0.789370         NaN
# num_hahas           NaN   1.000000  0.793677         NaN
# num_sads       0.789370   0.793677  1.000000    0.866861
# num_angrys          NaN        NaN  0.866861    1.000000

# %%
# plt.subplot(1,2,2)
plt.plot(page2.index, page2.num_reactions, 'b')
plt.xlabel('date')
plt.ylabel('num_reactions')
plt.title('Malaysiakini Post (Original)')
# Out:
# Text(0.5, 1.0, 'Malaysiakini Post (Original)')

# %% [markdown]
# ## Any periodicity

# %%
# Fast Fourier Transform (FFT)
Y = np.fft.fft(page2.num_reactions)

# %%
N = int(len(Y)/2+1)
dt = page2.index[-1] - page2.index[0]

print(dt.days/N)
fs = 1.0/(dt.days/N) 
print('dt= {} (Sample Time).'.format(dt.days/N))
print('fs= {} (Sampling Freq).'.format(fs))
# Out:
# 3.611940298507463
# dt= 3.611940298507463 (Sample Time).
# fs= 0.27685950413223137 (Sampling Freq).

# %%
X = np.linspace(0, fs/2, N, endpoint=True)
plt.plot(X, 2*np.abs(Y[:N])/N)
plt.xlabel('Frequency (per day)')
plt.ylabel('Magnitude')
# Out:
# Text(0,0.5,'Magnitude')

# %%
values = 2*np.abs(Y[1:N])/N
np.argmax(values)
print ("the possible seasonality is: {} days".format( 1/X[np.argmax(values)])) #
# Out:
# the possible seasonality is: 137.25373134328362 days
